# %%
# !python -m pip install ipykernel numpy pillow ipywidgets ipyevents
# Out:
# Requirement already satisfied: ipykernel in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (7.2.0)
# Collecting numpy
#   Downloading numpy-2.4.6-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: pillow in c:\Users\yangl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (12.2.0)
# Requirement already satisfied: ipywidgets in c:\Users\yangl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (8.1.8)
# Requirement already satisfied: ipyevents in c:\Users\yangl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.0.4)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (9.14.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (26.2)
# Requirement already satisfied: psutil>=5.7 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (6.5.6)
# Requirement already satisfied: traitlets>=5.4.0 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipykernel) (5.15.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\Users\yangl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\Users\yangl\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from jupyter-client>=8.8.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.10.0)
# Requirement already satisfied: six>=1.5 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\yangl\AppData\Roaming\Python\Python314\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Downloading numpy-2.4.6-cp314-cp314-win_amd64.whl (12.5 MB)
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.5 MB 15.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.4/12.5 MB 12.6 MB/s eta 0:00:01
#    -------------------- ------------------- 6.3/12.5 MB 13.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.5 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.5 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.5/12.5 MB 12.2 MB/s  0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-2.4.6
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\yangl\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
from PIL import Image
from io import BytesIO
import ipywidgets as widgets
from IPython.display import display
from ipyevents import Event
import time

# Fixed-point Newton fractal live demo
# Used fixed-point python code from stage 2 with a few changes
# For live browser demo, 320x240 is much faster.
WIDTH, HEIGHT = 320, 240

MAX_ITER = 30
SCALE = 4096
FRAC_BITS = 12

RE_MIN, RE_MAX = -2.0, 2.0
IM_MIN, IM_MAX = -1.5, 1.5

DEFAULT_STEP = int(round((RE_MAX - RE_MIN) * SCALE / (WIDTH - 1)))
DEFAULT_ZR0 = int(round(RE_MIN * SCALE))
DEFAULT_ZI0 = int(round(IM_MIN * SCALE))

ROOTS_F = [
    (1.0, 0.0),
    (-0.5, 0.8660254),
    (-0.5, -0.8660254)
]

ROOTS = [
    (int(round(r * SCALE)), int(round(i * SCALE)))
    for (r, i) in ROOTS_F
]

COL = np.array([
    [230, 57, 70],
    [42, 157, 143],
    [69, 123, 157]
], dtype=int)

TOL = int(round(0.03 * SCALE))

DENOM_MIN = 1


def tdiv(a, b):
    """Truncate toward zero, like Verilog signed division."""
    if b == 0:
        return 0

    q = abs(a) // abs(b)

    if (a < 0) != (b < 0):
        return -q
    else:
        return q


def mul(a, b):
    """Q12 multiplication."""
    return tdiv(a * b, SCALE)



# Convert zoom/pan into register-style values

def view_to_registers(zoom=1.0, pan_x=0, pan_y=0):

    step = int(round(DEFAULT_STEP / zoom))

    if step < 1:
        step = 1

    centre_r = DEFAULT_ZR0 + (WIDTH // 2) * DEFAULT_STEP
    centre_i = DEFAULT_ZI0 + (HEIGHT // 2) * DEFAULT_STEP

    centre_r = centre_r + pan_x * step
    centre_i = centre_i + pan_y * step

    zr0 = centre_r - (WIDTH // 2) * step
    zi0 = centre_i - (HEIGHT // 2) * step

    return int(zr0), int(zi0), int(step)


# Generate one fixed-point image

def generate_fixed_newton_image(zoom=1.0, pan_x=0, pan_y=0, max_iter=MAX_ITER):
    zr0, zi0, step = view_to_registers(zoom, pan_x, pan_y)

    img = np.zeros((HEIGHT, WIDTH, 3), dtype=np.uint8)

    for py in range(HEIGHT):
        for px in range(WIDTH):

            zr = zr0 + px * step
            zi = zi0 + py * step

            which = -1
            it = 0

            for it in range(max_iter):

                zr2 = mul(zr, zr) - mul(zi, zi)
                zi2 = tdiv(2 * zr * zi, SCALE)

                zr3 = mul(zr2, zr) - mul(zi2, zi)
                zi3 = mul(zr2, zi) + mul(zi2, zr)

                fr = zr3 - SCALE
                fi = zi3

                fpr = 3 * zr2
                fpi = 3 * zi2

                denom = mul(fpr, fpr) + mul(fpi, fpi)

                if denom <= DENOM_MIN:
                    break

                numr = mul(fr, fpr) + mul(fi, fpi)
                numi = mul(fi, fpr) - mul(fr, fpi)

                dr = tdiv(numr * SCALE, denom)
                di = tdiv(numi * SCALE, denom)

                zr = zr - dr
                zi = zi - di

                for k, (rr, ri) in enumerate(ROOTS):
                    if abs(zr - rr) < TOL and abs(zi - ri) < TOL:
                        which = k
                        break

                if which >= 0:
                    break

            if which < 0:
                img[py, px] = (0, 0, 0)

            else:
                shade256 = 256 - (it * 256) // max_iter

                if shade256 < 64:
                    shade256 = 64

                r = (int(COL[which][0]) * shade256) >> 8
                g = (int(COL[which][1]) * shade256) >> 8
                b = (int(COL[which][2]) * shade256) >> 8

                img[py, px] = (r, g, b)

    return img



# Convert NumPy image to PNG bytes for browser display

def image_to_png_bytes(img_array):
    image = Image.fromarray(img_array)
    buffer = BytesIO()
    image.save(buffer, format="PNG")
    return buffer.getvalue()


# Jupyter live display

DISPLAY_WIDTH = 640
DISPLAY_HEIGHT = 480

zoom = 1.0
pan_x = 0
pan_y = 0

dragging = False
last_mouse_x = 0
last_mouse_y = 0

last_render_time = 0
RENDER_PERIOD = 0.1


image_widget = widgets.Image(
    format="png",
    width=DISPLAY_WIDTH,
    height=DISPLAY_HEIGHT
)

status = widgets.Label()
reset_button = widgets.Button(description="Reset View")


def render(force=False):
    global last_render_time

    now = time.time()

    if force or now - last_render_time > RENDER_PERIOD:
        last_render_time = now

        img = generate_fixed_newton_image(
            zoom=zoom,
            pan_x=pan_x,
            pan_y=pan_y,
            max_iter=MAX_ITER
        )

        image_widget.value = image_to_png_bytes(img)

        zr0, zi0, step = view_to_registers(zoom, pan_x, pan_y)

        status.value = (
            f"Zoom = {zoom:.2f}, "
            f"Pan X = {pan_x}, "
            f"Pan Y = {pan_y}, "
            f"ZR0 = {zr0}, "
            f"ZI0 = {zi0}, "
            f"STEP = {step}"
        )


# Mouse controls

mouse_events = Event(
    source=image_widget,
    watched_events=[
        "mousedown",
        "mousemove",
        "mouseup",
        "mouseleave",
        "wheel"
    ]
)

mouse_events.prevent_default_action = True


def handle_mouse_event(event):
    global zoom, pan_x, pan_y
    global dragging, last_mouse_x, last_mouse_y

    event_type = event["type"]

    x = event.get("relativeX", 0)
    y = event.get("relativeY", 0)

    if event_type == "mousedown":
        dragging = True
        last_mouse_x = x
        last_mouse_y = y

    elif event_type == "mousemove" and dragging:
        dx = x - last_mouse_x
        dy = y - last_mouse_y

        last_mouse_x = x
        last_mouse_y = y

        dx_pixels = dx * WIDTH / DISPLAY_WIDTH
        dy_pixels = dy * HEIGHT / DISPLAY_HEIGHT

        pan_x -= int(round(dx_pixels))
        pan_y -= int(round(dy_pixels))

        render(force=False)

    elif event_type == "mouseup":
        dragging = False
        render(force=True)

    elif event_type == "mouseleave":
        dragging = False

    elif event_type == "wheel":
        delta_y = event.get("deltaY", 0)

        if delta_y < 0:
            zoom *= 1.2
        else:
            zoom /= 1.2

        if zoom < 0.5:
            zoom = 0.5

        if zoom > 50:
            zoom = 50

        render(force=True)


mouse_events.on_dom_event(handle_mouse_event)


# Reset button

def reset_view(button):
    global zoom, pan_x, pan_y

    zoom = 1.0
    pan_x = 0
    pan_y = 0

    render(force=True)


reset_button.on_click(reset_view)


# Display

display(image_widget)
display(widgets.HBox([reset_button]))
display(status)

render(force=True)
# Out:
# Image(value=b'', height='480', width='640')
# HBox(children=(Button(description='Reset View', style=ButtonStyle()),))
# Label(value='')

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\yangl\AppData\Local\Python\pythoncore-3.14-64\python.exe
